# %% [markdown]
# # 1.0. Geral Information

# %%
Image("../img/rossman.png")

# %% [markdown]
# ## 1.1 Imports

# %%
import math
import datetime
import warnings
import inflection

import pandas  as pd
import numpy   as np
import seaborn as sns
import weightedstats       as ws
import matplotlib.pyplot   as plt
import matplotlib.gridspec as gridspec

from scipy                import stats
from tabulate             import tabulate
from IPython.core.display import HTML
from IPython.display      import Image

# %% [markdown]
# ## 1.2 Helper Functions

# %%
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (20,15)
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## 1.3 Loading Data

# %%
df_sales_raw = pd.read_csv( '../data/train.csv', low_memory=False )
df_store_raw = pd.read_csv( '../data/store.csv', low_memory=False )

df_raw = pd.merge( df_sales_raw, df_store_raw, how='left', on='Store' )

# %% [markdown]
# # 2.0. Clearing Data & Statistic Descriptive

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 2.1 Rename Columns

# %%
old_cols = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

snake_case = lambda x: inflection.underscore( x )

new_cols = list( map( snake_case, old_cols ) )

df1.columns = new_cols

# %% [markdown]
# ## 2.2 Data Dimension

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Numberof Columns: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Numberof Columns: 18

# %% [markdown]
# ## 2.3 Change Types

# %%
df1['date'] = pd.to_datetime(df1['date'])

df1['assortment'] = df1['assortment'].apply( lambda x: 'basic' if x == 'a' else 
                                           'extra' if x == 'b' else 'extended')

df1['state_holiday'] = df1['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 
                                                  'easter_holiday' if x == 'b' else
                                                  'christmas' if x == 'c' else 'regular_day')

# %% [markdown]
# ## 2.4 Check Na

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 2.5 Fillout Na

# %%
#competition_distance
df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

#competition_open_since_month
df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] )
                                                            else x['competition_open_since_month'], axis=1 )

#competition_open_since_year 
df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] )
                                                           else x['competition_open_since_year'], axis=1 )

#promo2_since_week
df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan( x['promo2_since_week'] )
                                                           else x['promo2_since_week'], axis=1 )

#promo2_since_year
df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] )
                                                           else x['promo2_since_year'], axis=1 )

#promo_interval  
month_map = {1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

df1['month_map'] = df1['date'].dt.month.map( month_map )

df1['promo_interval'].fillna(0, inplace=True)

df1['is_promo']= df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 
                                                            else 1 if x['month_map'] in x['promo_interval'].split(',') 
                                                            else 0, axis=1 )

# %% [markdown]
# ## 2.6 Change Types

# %%
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype('int64')
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype('int64')

df1['promo2_since_week'] = df1['promo2_since_week'].astype('int64')
df1['promo2_since_year'] = df1['promo2_since_year'].astype('int64')

# %% [markdown]
# ## 2.7 Statistic Descriptive

# %%
num_att = df1.select_dtypes( include=['int64', 'float64'] )
cat_att = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
# Central Tendency ( Mean, Median, Trimmed Mean )
c1 = pd.DataFrame( num_att.apply( np.mean ) ).T
c2 = pd.DataFrame( num_att.apply( np.median ) ).T

# Trimmed Mean
t1 = pd.DataFrame( stats.trim_mean( num_att, 0.2 ) ).T
t1.columns = ['store', 'day_of_week', 'sales', 'customers', 'open', 'promo',
               'school_holiday', 'competition_distance',
               'competition_open_since_month', 'competition_open_since_year', 'promo2',
               'promo2_since_week', 'promo2_since_year', 'is_promo']
                  
# Dispersion Means ( Std, Min, Max, Range, Skew, Kurtosis )
d1 = pd.DataFrame( num_att.apply( np.std ) ).T
d2 = pd.DataFrame( num_att.apply( min ) ).T
d3 = pd.DataFrame( num_att.apply( max ) ).T
d4 = pd.DataFrame( num_att.apply( lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame( num_att.apply( lambda x: x.skew() ) ).T
d6 = pd.DataFrame( num_att.apply( lambda x: x.kurtosis() ) ).T

m = pd.concat( [ d2, d3, c1, c2, d1, d4, d5, d6 ] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'mean', 'median', 'std', 'range', 'skew', 'kurtosis']

display( m )
display( t1 )
# Out:
#                       attributes     min       max         mean  median  \
# 0                          store     1.0    1115.0   558.429727   558.0
# 1                    day_of_week     1.0       7.0     3.998341     4.0
# 2                          sales     0.0   41551.0  5773.818972  5744.0
# 3                      customers     0.0    7388.0   633.145946   609.0
# 4                           open     0.0       1.0     0.830107     1.0
# 5                          promo     0.0       1.0     0.381515     0.0
# 6                 school_holiday     0.0       1.0     0.178647     0.0
# 7           competition_distance    20.0  200000.0  5935.442677  2330.0
# 8   competition_open_since_month     1.0      12.0     6.786849     7.0
# 9    competition_open_since_year  1900.0    2015.0  2010.324840  2012.0
# 10                        promo2     0.0       1.0     0.500564     1.0
# 11             promo2_since_week     1.0      52.0    23.619033    22.0
# ...

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
auxy = df1[df1['sales'] != 0]
sns.distplot( np.log1p( auxy['sales'] ) );

# %%
aux1 = df1[(df1['sales'] > 0) & (df1['open'] != 0)  & (df1['state_holiday'] != 'regular_day')]

plt.subplot( 1, 3, 1 );
sns.boxplot( x='assortment', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 );
sns.boxplot( x='state_holiday', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 );
sns.boxplot( x='store_type', y='sales', data=aux1 );

# %% [markdown]
# # 3.0. Feature Engineering

# %% [markdown]
# ## 3.1 Mind Map with Hypothesis

# %%
Image('../img/mind_map.png')

# %% [markdown]
# ## 3.2 Final Hypotesis List

# %% [markdown]
# **1.** Lojas com maior sortimento, deveriam vender mais.
#
# **2.** Lojas com competidores mais proximos deveriam vender menos.
#
# **3.** Lojas com competidores a mais tempo deveriam vender mais.
#
# **4.** Lojas com promoçoes ativas a mais tempo deveriam vender mais.
#
# **5.** Lojas com mais dias de promoção deveriam vender mais.
#
# **6.** Lojas com promoçoes consecutivas deveriam vender mais.
#
# **7.** Lojas abertas nos feriados natalinos deveriam vender mais.
#
# **8.** Lojas deveriam vender mais ao longo dos anos.
#
# **9.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **10.** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **11.** Lojas deveriam vender menos nos finais de semana.
#
# **12.** Lojas deveriam vender menos nos feriados escolares.
#
# **13.** Lojas deveriam vender manos no segundo semestre do ano.

# %% [markdown]
# ## 3.3 Feature Engineering

# %%
df2 = df1.copy()

# %%
# Year
df2['year'] = df2['date'].dt.year

# Month
df2['month'] = df2['date'].dt.month

# Day
df2['day'] = df2['date'].dt.day

# Year Week
df2['week_of_year'] = df2['date'].dt.isocalendar().week

# Week of Year
df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )

# Competition Since
df2['competition_since'] = df2.apply( lambda x: datetime.datetime( year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1 ), axis=1 )
df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] ) / 30 ).apply( lambda x: x.days ).astype('int64')

# Promo Since
df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w') - datetime.timedelta( days= 7 ) )
df2['promo_since_week'] = ( ( df2['date'] - df2['promo_since'] ) / 7 ).apply( lambda x: x.days ).astype('int64')

# %% [markdown]
# # 4.0. Data Filtering

# %%
df3 = df2.copy()

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

df3 = df3.drop( ['promo_interval', 'open', 'month_map', 'customers'], axis=1)
cat_att = cat_att.drop( ['month_map', 'promo_interval'], axis=1 )
num_att = num_att.drop( ['open', 'customers'], axis=1 )

# %% [markdown]
# # 5.0. Exploration Data Analysis

# %%
df4 = df3.copy()

# %% [markdown]
# ## 5.1. Univariable Analysis

# %% [markdown]
# ### 5.1.1 Response Variable

# %%
sns.distplot( np.log1p( df4['sales'] ), color='Magenta' );

# %% [markdown]
# ### 5.1.2 Numerical Variable

# %%
num_att.hist( bins=25, color='#030ffc' );

# %% [markdown]
# ### 5.1.3 Categorical Variable

# %%
# State Holiday
aux1 = df4[df4['state_holiday'] != 'regular_day']

plt.subplot( 3, 2, 1 )
sns.countplot( aux1['state_holiday'], palette = 'hls' );

plt.subplot( 3, 2, 2 )
sns.kdeplot( df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', shade=True );
sns.kdeplot( df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', shade=True );
sns.kdeplot( df4[df4['state_holiday'] == 'christmas']['sales'], label='chirstmans', shade=True );
plt.legend();

# Store Type
plt.subplot( 3, 2, 3 )
sns.countplot( df4['store_type'], palette='hls' );

plt.subplot( 3, 2, 4 )
sns.kdeplot( df4[df4['store_type'] == 'a']['sales'], label='a', shade=True );
sns.kdeplot( df4[df4['store_type'] == 'b']['sales'], label='b', shade=True );
sns.kdeplot( df4[df4['store_type'] == 'c']['sales'], label='c', shade=True );
sns.kdeplot( df4[df4['store_type'] == 'd']['sales'], label='d', shade=True );
plt.legend();

# Assortment
plt.subplot( 3, 2, 5 )
sns.countplot( df4['assortment'], palette='hls' );

plt.subplot( 3, 2, 6 )
sns.kdeplot( df4[df4['assortment'] == 'basic']['sales'], label='basic', shade=True );
sns.kdeplot( df4[df4['assortment'] == 'extra']['sales'], label='extra', shade=True );
sns.kdeplot( df4[df4['assortment'] == 'extended']['sales'], label='extended', shade=True );
plt.legend();

# %% [markdown]
# ## 5.2. Bivariable Analysis

# %% [markdown]
# ### **H1.** Lojas com maior sortimento, deveriam vender mais.
# **Falsa** Lojas com maior sortimento, vendem menos.

# %%
aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
aux2 = df4[['assortment', 'month', 'sales']].groupby(['assortment', 'month']).sum().reset_index()
aux3 = df4[['assortment', 'year_week', 'sales']].groupby(['assortment', 'year_week']).sum().reset_index()

plt.subplot( 2, 2, 1 )
sns.barplot( x='assortment', y='sales', data=aux1, palette='hls');

plt.subplot( 2, 2, 2 )
sns.barplot( x='assortment', y='sales', hue='month', data=aux2, palette='hls' );

aux3.pivot( index='year_week', columns='assortment', values='sales' ).plot();
aux3[aux3['assortment'] == 'extra'].plot();

# %% [markdown]
# ### **H2.** Lojas com competidores mais proximos deveriam vender menos.
# **Falsa** Lojas com competidores mais proximos, vendem mais.

# %%
aux1 = df4[['sales', 'competition_distance']].groupby('competition_distance').sum().reset_index()

bins = list( np.arange( 0, 20000, 1000 ) )
aux1['comp_dist_binned'] = pd.cut( aux1['competition_distance'], bins=bins )

plt.subplot( 3, 2, 1 )
sns.barplot( x='comp_dist_binned', y='sales', data=aux1 );
plt.xticks( rotation=90 );

plt.subplot( 3, 2, 2 )
sns.scatterplot( x='competition_distance', y='sales', data=aux1 );

plt.subplot( 3, 2, 5 )
sns.heatmap( aux1.corr( method='pearson' ), cmap="YlGnBu", annot=True );

plt.subplot( 3, 2, 6 )
sns.regplot( x='competition_distance', y='sales', data=aux1 );

# %% [markdown]
# ### **H3.** Lojas com competidores a mais tempo deveriam vender mais.
# **Falsa** Lojas com competidores a mais tempo, vendem menos.

# %%
aux1 = df4[['sales', 'competition_time_month']].groupby('competition_time_month').sum().reset_index()
aux2 = aux1[(aux1['competition_time_month'] < 100) & (aux1['competition_time_month'] != 0)]
aux3 = aux1[(aux1['competition_time_month'] > 120) & (aux1['competition_time_month'] != 0)]

grid = gridspec.GridSpec( 2, 3 )

plt.subplot( grid[0, :-1] )
sns.barplot( x='competition_time_month', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( grid[1, :-1] )
sns.barplot( x='competition_time_month', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot( grid[:, 2] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap="YlGnBu" )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **H4.** Lojas com promoções ativas a mais tempo deveriam vender mais.
# **Falso** Lojas com promoções ativas a mais tempo,vendem menos.

# %%
aux1 = df4[['promo_since_week', 'sales']].groupby('promo_since_week').sum().reset_index()
aux2 = aux1[aux1['promo_since_week'] > 0] # Extended Promo
aux3 = aux1[aux1['promo_since_week'] < 0] # Traditional Promo

grid = gridspec.GridSpec( 3, 2 )

plt.subplot( grid[0, 0] )
sns.barplot( x='promo_since_week', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot( grid[0,1] )
sns.barplot( x='promo_since_week', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( grid[1,0] )
sns.regplot( x='promo_since_week', y='sales', data=aux3 );

plt.subplot( grid[1,1] )
sns.regplot( x='promo_since_week', y='sales', data=aux2 );

plt.subplot( grid[2,:] )
sns.heatmap( aux1.corr( method='pearson'), annot=True, cmap='YlGnBu' );
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **H5.** <s> Lojas com mais dias de promoção deveriam vender mais. </s>

# %%
aux1 = df4[['day', 'is_promo', 'sales']].groupby(['is_promo', 'day']).sum().reset_index()

plt.subplot( 2, 1, 1 )
sns.barplot( x='day', y='sales', hue='is_promo', data=aux1 );

aux1.pivot( columns='is_promo', values='sales', index='day' ).plot();

# %% [markdown]
# ### **H6.** Lojas com promoções consecutivas deveriam vender mais.
# **Falsa** Lojas com mais promoções consecutivas, vendem menos.

# %%
# Traditional Promo & Extended Promo
aux1 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 1 )][['year_week', 'sales']].groupby('year_week').sum().reset_index()
ax = aux1.plot();

# Traditional Promo
aux2 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 0 )][['year_week', 'sales']].groupby('year_week').sum().reset_index()
aux2.plot( ax=ax );

ax.legend( labels=['Traditional & Extended', 'Extended'] );

# %% [markdown]
# ### **H7.** Lojas abertas nos feriados natalinos deveriam vender mais.
# **Falsa** Lojas aberta snos feriados natalinos, vendem menos.

# %%
aux1 = df4[['state_holiday', 'year', 'sales']].groupby(['state_holiday', 'year']).sum().reset_index()
aux1 = aux1[aux1['state_holiday'] != 'regular_day']

plt.subplot( 1, 2, 1 )
sns.barplot( x='year', y='sales', hue='state_holiday', data=aux1, palette='hls' );

plt.subplot( 1, 2, 2 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **H8.** Lojas deveriam vender mais ao longo dos anos.
# **Falsa** Lojas não vendem mais ao longo dos anos.

# %%
aux1 = df4[['year', 'sales']].groupby('year').sum().reset_index()
aux2 = df4[['month', 'year', 'sales']].groupby(['month', 'year']).sum().reset_index()

grid = gridspec.GridSpec( 2, 2 )

plt.subplot( grid[0, 0] )
sns.barplot( x='year', y='sales', data=aux1 );

plt.subplot( grid[0, 1] )
sns.barplot( x='month', y='sales', hue='year', data=aux2 );

plt.subplot( grid[1, 0] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='nipy_spectral_r');

plt.subplot( grid[1, 1] )
sns.regplot( x='year', y='sales', data=aux1 );

# %% [markdown]
# ### **H9.** Lojas deveriam vender mais no segundo semestre do ano.
# **Falsa** Lojas vendem menos no segundo semestre do ano.

# %%
aux1 = df4[['month', 'sales']].groupby('month').sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='month', y='sales', data=aux1, palette='hls' );

plt.subplot( 1, 3, 2 )
sns.regplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='Spectral');

# %% [markdown]
# ### **H10**. Lojas deveriam vender mais depois do dia 10 de cada mes.
# **Verdadeiro** Lojas realmente vendem mais depois do dia 10 de cada mes.

# %%
aux1 = df4[['day', 'sales']].groupby('day').sum().reset_index()
aux1['before_10'] = aux1['day'].apply( lambda x: 'before_10' if x <= 10 else 'after_10')
aux2 = aux1[['before_10', 'sales']].groupby('before_10').sum().reset_index()

grid = gridspec.GridSpec( 2, 3 )

plt.subplot( grid[0, 0] )
sns.barplot( x='day', y='sales', hue='before_10', data=aux1, palette='hls' );
plt.xticks(rotation=90)

plt.subplot( grid[0, 1] )
sns.barplot( x='before_10', y='sales', data=aux2 );

plt.subplot( grid[0, 2] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='Spectral');

# %% [markdown]
# ### **H11**. Lojas deveriam vender menos nos finais de semana.
# **Verdadeiro** Lojas  vendem menos nos finais de semana.

# %%
aux1 = df4[['day_of_week', 'sales']].groupby('day_of_week').sum().reset_index()

grid = gridspec.GridSpec( 2, 2 )

plt.subplot( grid[0, 0] )
sns.barplot( x='day_of_week', y='sales', data=aux1, palette='hls' );
plt.xticks(rotation=90)

plt.subplot( grid[0, 1] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='Spectral');

# %% [markdown]
# ### **H12**. Lojas deveriam vender menos nos feriados escolares.
# **Verdadeiro** Lojas vendem menos nos feriados excolares, exeto no mese de Agosto.

# %%
aux1 = df4[['year', 'sales']].groupby( ['school_holiday', 'month'] ).sum().reset_index()

plt.subplot( 1, 2, 1 )
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux1 );

plt.subplot( 1, 2, 2 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='Spectral' );

# %%
aux1 = df4[['school_holiday', 'month', 'sales']].groupby( ['school_holiday', 'month'] ).sum().reset_index()

plt.subplot( 1, 2, 1 )
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux1 );

plt.subplot( 1, 2, 2 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True, cmap='Spectral' );

# %% [markdown]
# ## 5.3. General Hypothesis Resume

# %%
table = [ ['H1', 'High'],
          ['H2', 'High'],
          ['H3', 'Normal'],
          ['H4', 'High'],
          ['H5', 'Normal'],
          ['H6', 'Normal'],
          ['H7', 'Low'],
          ['H8', 'High'],
          ['H9', 'Low'],
          ['H10', 'Low'],
          ['H11', 'Low'],
          ['H12', 'Normal'] ]

print( tabulate( table, headers=['Hypotesis', 'Importance'], tablefmt="github" ) )
# Out:
# | Hypotesis   | Importance   |
# |-------------|--------------|
# | H1          | High         |
# | H2          | High         |
# | H3          | Normal       |
# | H4          | High         |
# | H5          | Normal       |
# | H6          | Normal       |
# | H7          | Low          |
# | H8          | High         |
# | H9          | Low          |
# | H10         | Low          |
# | H11         | Low          |
# | H12         | Normal       |

# %% [markdown]
# ## 5.3. Multivariable Analysis

# %% [markdown]
# # 6.0. Data Preparation
